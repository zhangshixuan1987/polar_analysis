# %% [markdown]
# # Weather Regimes Analysis Diagnostics Workflow
#
# This notebook runs spatial weather regime clustering using the K-means algorithm to identify typical atmospheric circulation patterns (regimes) and their occurrences over specified polar regions.

# %%
import os
import sys
import collections

# Ensure our shared libraries are discoverable
sys.path.append("..")
from polar_utils.common import Case
from polar_utils.weather_regimes import run_weather_regime_analysis

# %%
# Global Configuration Paths
top_path = "/lcrc/group/e3sm2/ac.szhang/E3SMv21_testings/v3_polar_paper"
run_path = "/lcrc/group/e3sm/ac.szhang/acme_scratch/data/pcmdi/model/monthly"

# Region: Amundsen Sea Sector
region = {'west': 170., 'east': 298., 'south': -80., 'north': -60.}
regnam = 'Amundsen_Sea'
season = 'DJF'

# %% [markdown]
# ## 1. Run Weather Regime Clustering Analysis

# %%
out_path = os.path.join(top_path, "fig_data", "weather_regimes", "raw_index")
fig_path = os.path.join(top_path, "polar_analysis", "9_weather_regimes", "figure")

case_dict = collections.OrderedDict()
case_dict["v2_1-SORRM"] = Case(os.path.join(run_path, "e3sm/historical/Amon/psl/e3sm.historical.v2_1-SORRM.0701.mon.psl.195001-201412.nc"), "PSL", "blue", "v2_1-SORRM")
run_weather_regime_analysis(fig_path, out_path, "e3sm", "historical", "0701", "195001-201412", "195001-201412", 
                             case_dict, region, regnam, season, n_clusters=[4])
